# %%
import pandas as pd
import numpy as np
import pickle
import torch
from transformers import BertTokenizer, BertModel
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv(r'data/mini-job-rec-dataset - jobs_data.csv')

# %%
df
# Out:
#     job_id                       job_title        specialization  \
# 0        1               Junior Accountant  Accounting & Finance
# 1        2               Financial Analyst  Accounting & Finance
# 2        3                  Tax Consultant  Accounting & Finance
# 3        4                   Audit Manager  Accounting & Finance
# 4        5  Entry-Level Software Developer    Software Developer
# 5        6            Full-Stack Developer    Software Developer
# 6        7            Mobile App Developer    Software Developer
# 7        8              Software Architect                   NaN
# 8        9                    Receptionist                 Admin
# 9       10             Executive Assistant                 Admin
# 10      11                  Office Manager                 Admin
# 11      12                HR Administrator                 Admin
# 12      13            Sales Representative                 Sales
# 13      14                 Account Manager                 Sales
# 14      15    Business Development Manager                 Sales
# 15      16                  Sales Director                 Sales
# 16      17           IT Support Specialist                    IT
# 17      18           Network Administrator                    IT
# 18      19           Cybersecurity Analyst                    IT
# 19      20                  Data Scientist                    IT
# 20      21              Payroll Specialist  Accounting & Finance
# 21      22                  Credit Analyst  Accounting & Finance
# 22      23               Investment Banker  Accounting & Finance
# 23      24                    Risk Manager  Accounting & Finance
# 24      25                       QA Tester    Software Developer
# 25      26               Backend Developer    Software Developer
# 26      27              Frontend Developer    Software Developer
# 27      28                 DevOps Engineer    Software Developer
# 28      29        Administrative Assistant                 Admin
# 29      30                Data Entry Clerk                 Admin
# 30      31            Customer Service Rep                 Sales
# 31      32                  Sales Engineer                   NaN
# 32      33         Territory Sales Manager                 Sales
# 33      34           Channel Sales Manager                 Sales
# 34      35            Help Desk Technician                    IT
# 35      36            System Administrator                    IT
# 36      37       Cloud Solutions Architect                    IT
# 37      38          Database Administrator                    IT
# 38      39              Compliance Officer  Accounting & Finance
# 39      40                 Cost Accountant  Accounting & Finance
#
#                                       job_description  \
# 0   Assists in financial record-keeping, prepares ...
# 1   Analyzes financial data to assist in business ...
# 2     Advises clients on tax planning and compliance.
# 3   Oversees auditing processes, ensures complianc...
# 4                                                 NaN
# 5   Develops front-end and back-end aspects of web...
# 6   Specializes in creating applications for mobil...
# 7   Designs the overall structure of software syst...
# 8   Manages front desk, answers calls, and assists...
# 9   Provides comprehensive support to senior execu...
# 10  Oversees administrative functions, manages off...
# 11  Supports HR tasks such as recruitment, employe...
# 12  Generates leads, sells products or services, a...
# 13  Manages client accounts, identifies customer n...
# 14  Identifies business opportunities, builds clie...
# 15  Leads the sales department, sets targets, and ...
# 16  Provides technical support, resolves IT issues...
# 17  Manages and supports the organization's networ...
# 18  Protects systems from cyber threats, monitors ...
# 19  Analyzes complex data sets to identify pattern...
# 20  Manages payroll processing, ensures accuracy a...
# 21  Assesses credit risk, evaluates financial stat...
# 22  Advises on and manages large financial transac...
# 23  Identifies financial risks and develops strate...
# 24  Tests software applications for bugs, issues, ...
# 25  Focuses on server-side logic, integration, and...
# 26  Develops the user interface and front-end logi...
# 27  Streamlines software development and deploymen...
# 28  Assists in daily office needs and managing gen...
# 29  Inputs and updates data into a database or doc...
# 30  Handles customer inquiries, resolves issues, a...
# 31  Combines technical knowledge with sales skills...
# 32  Manages and grows sales within a specific geog...
# 33  Manages sales through different channels, deve...
# 34  Provides technical support to users, troublesh...
# 35  Manages and troubleshoots an organization's so...
# 36  Designs and deploys scalable, reliable, and ef...
# 37  Maintains and secures the organization's datab...
# 38  Ensures financial operations and transactions ...
# 39  Analyzes production costs, prepares budget rep...
#
#                                             skillsets year_of_experience
# 0   Accounting principles, Excel, attention to detail                1-2
# 1            Financial modeling, data analysis, Excel                2-4
# 2           Tax law, analytical skills, communication                3-5
# 3             Auditing, critical thinking, leadership                 5+
# 4                    Programming languages, HTML, CSS                0-2
# 5         Full-stack development, database management                3-5
# 6       Mobile development, UI/UX design, Java/Kotlin                2-4
# 7              System design, programming, leadership                 6+
# 8             Customer service, organizational skills                0-2
# 9              Time management, discretion, MS Office                NaN
# 10             Leadership, organization, multitasking                 4+
# 11           HR policies, communication, organization                2-4
# 12      Sales techniques, communication, CRM software                1-3
# 13               Relationship management, negotiation                3-5
# 14                Market research, strategic planning                 4+
# 15    Leadership, market analysis, strategic thinking                 6+
# 16                 Technical support, problem-solving                1-3
# 17             Network management, security protocols                2-4
# 18  Cybersecurity, threat analysis, attention to d...                3-5
# 19          Data analysis, machine learning, Python/R                 4+
# 20                                                NaN                2-3
# 21                Financial analysis, risk assessment                3-4
# 22        Financial modelling, negotiation, valuation                 5+
# 23                 Risk management, analytical skills                 4+
# 24      Testing, attention to detail, problem-solving                1-2
# 25              Node JS, Python, programming language                3-5
# 26         Web technologies, UI/UX design, JavaScript                2-4
# 27                  Automation tools, cloud platforms                 4+
# 28     Organizational skills, multitasking, MS Office                1-3
# 29      Typing speed, accuracy, basic computer skills                0-2
# 30          Customer service, communication, patience                1-2
# 31                  Technical expertise, sales skills                3-5
# 32               Sales techniques, regional knowledge                 4+
# 33             Channel management, strategic planning                 4+
# 34    Customer service, IT knowledge, problem-solving                1-2
# 35  System management, network skills, attention t...                2-4
# 36               Cloud platforms, architecture design                 5+
# 37                           Database management, SQL                3-5
# 38              Regulatory knowledge, detail-oriented                3-4
# 39                           Cost analysis, budgeting                3-4

# %%
# check for NaN values in df
df.isna().sum()
# Out:
# job_id                0
# job_title             0
# specialization        2
# job_description       1
# skillsets             1
# year_of_experience    1
# dtype: int64

# %%
# fill job_description and skillsets NaN values with empty string
df["job_description"] = df["job_description"].fillna("")
df["skillsets"] = df["skillsets"].fillna("")

# %%
# # only interested in minimum years of experience
# df['min_year_of_experience'] = df['year_of_experience'].apply(lambda x: int(x.split('-')[0]) if '-' in x else int(x.replace('+', '')))

# drop year_of_experience (not required)
df = df.drop("year_of_experience", axis=1)

# add combine_description column for training specialization classifier
df["combined_description"] = df['job_title'] + " " + df['job_description'] + " " + df['skillsets']

# combine IT and Software Developer into IT & Software Developer column
df["specialization"] = df["specialization"].apply(lambda x: "IT & Software Developer" if x in ["IT", "Software Developer"] else x)

# %%
df
# Out:
#     job_id                       job_title           specialization  \
# 0        1               Junior Accountant     Accounting & Finance
# 1        2               Financial Analyst     Accounting & Finance
# 2        3                  Tax Consultant     Accounting & Finance
# 3        4                   Audit Manager     Accounting & Finance
# 4        5  Entry-Level Software Developer  IT & Software Developer
# 5        6            Full-Stack Developer  IT & Software Developer
# 6        7            Mobile App Developer  IT & Software Developer
# 7        8              Software Architect                      NaN
# 8        9                    Receptionist                    Admin
# 9       10             Executive Assistant                    Admin
# 10      11                  Office Manager                    Admin
# 11      12                HR Administrator                    Admin
# 12      13            Sales Representative                    Sales
# 13      14                 Account Manager                    Sales
# 14      15    Business Development Manager                    Sales
# 15      16                  Sales Director                    Sales
# 16      17           IT Support Specialist  IT & Software Developer
# 17      18           Network Administrator  IT & Software Developer
# 18      19           Cybersecurity Analyst  IT & Software Developer
# 19      20                  Data Scientist  IT & Software Developer
# 20      21              Payroll Specialist     Accounting & Finance
# 21      22                  Credit Analyst     Accounting & Finance
# 22      23               Investment Banker     Accounting & Finance
# 23      24                    Risk Manager     Accounting & Finance
# 24      25                       QA Tester  IT & Software Developer
# 25      26               Backend Developer  IT & Software Developer
# 26      27              Frontend Developer  IT & Software Developer
# 27      28                 DevOps Engineer  IT & Software Developer
# 28      29        Administrative Assistant                    Admin
# 29      30                Data Entry Clerk                    Admin
# 30      31            Customer Service Rep                    Sales
# 31      32                  Sales Engineer                      NaN
# 32      33         Territory Sales Manager                    Sales
# 33      34           Channel Sales Manager                    Sales
# 34      35            Help Desk Technician  IT & Software Developer
# 35      36            System Administrator  IT & Software Developer
# 36      37       Cloud Solutions Architect  IT & Software Developer
# 37      38          Database Administrator  IT & Software Developer
# 38      39              Compliance Officer     Accounting & Finance
# 39      40                 Cost Accountant     Accounting & Finance
#
#                                       job_description  \
# 0   Assists in financial record-keeping, prepares ...
# 1   Analyzes financial data to assist in business ...
# 2     Advises clients on tax planning and compliance.
# 3   Oversees auditing processes, ensures complianc...
# 4
# 5   Develops front-end and back-end aspects of web...
# 6   Specializes in creating applications for mobil...
# 7   Designs the overall structure of software syst...
# 8   Manages front desk, answers calls, and assists...
# 9   Provides comprehensive support to senior execu...
# 10  Oversees administrative functions, manages off...
# 11  Supports HR tasks such as recruitment, employe...
# 12  Generates leads, sells products or services, a...
# 13  Manages client accounts, identifies customer n...
# 14  Identifies business opportunities, builds clie...
# 15  Leads the sales department, sets targets, and ...
# 16  Provides technical support, resolves IT issues...
# 17  Manages and supports the organization's networ...
# 18  Protects systems from cyber threats, monitors ...
# 19  Analyzes complex data sets to identify pattern...
# 20  Manages payroll processing, ensures accuracy a...
# 21  Assesses credit risk, evaluates financial stat...
# 22  Advises on and manages large financial transac...
# 23  Identifies financial risks and develops strate...
# 24  Tests software applications for bugs, issues, ...
# 25  Focuses on server-side logic, integration, and...
# 26  Develops the user interface and front-end logi...
# 27  Streamlines software development and deploymen...
# 28  Assists in daily office needs and managing gen...
# 29  Inputs and updates data into a database or doc...
# 30  Handles customer inquiries, resolves issues, a...
# 31  Combines technical knowledge with sales skills...
# 32  Manages and grows sales within a specific geog...
# 33  Manages sales through different channels, deve...
# 34  Provides technical support to users, troublesh...
# 35  Manages and troubleshoots an organization's so...
# 36  Designs and deploys scalable, reliable, and ef...
# 37  Maintains and secures the organization's datab...
# 38  Ensures financial operations and transactions ...
# 39  Analyzes production costs, prepares budget rep...
#
#                                             skillsets  \
# 0   Accounting principles, Excel, attention to detail
# 1            Financial modeling, data analysis, Excel
# 2           Tax law, analytical skills, communication
# 3             Auditing, critical thinking, leadership
# 4                    Programming languages, HTML, CSS
# 5         Full-stack development, database management
# 6       Mobile development, UI/UX design, Java/Kotlin
# 7              System design, programming, leadership
# 8             Customer service, organizational skills
# 9              Time management, discretion, MS Office
# 10             Leadership, organization, multitasking
# 11           HR policies, communication, organization
# 12      Sales techniques, communication, CRM software
# 13               Relationship management, negotiation
# 14                Market research, strategic planning
# 15    Leadership, market analysis, strategic thinking
# 16                 Technical support, problem-solving
# 17             Network management, security protocols
# 18  Cybersecurity, threat analysis, attention to d...
# 19          Data analysis, machine learning, Python/R
# 20
# 21                Financial analysis, risk assessment
# 22        Financial modelling, negotiation, valuation
# 23                 Risk management, analytical skills
# 24      Testing, attention to detail, problem-solving
# 25              Node JS, Python, programming language
# 26         Web technologies, UI/UX design, JavaScript
# 27                  Automation tools, cloud platforms
# 28     Organizational skills, multitasking, MS Office
# 29      Typing speed, accuracy, basic computer skills
# 30          Customer service, communication, patience
# 31                  Technical expertise, sales skills
# 32               Sales techniques, regional knowledge
# 33             Channel management, strategic planning
# 34    Customer service, IT knowledge, problem-solving
# 35  System management, network skills, attention t...
# 36               Cloud platforms, architecture design
# 37                           Database management, SQL
# 38              Regulatory knowledge, detail-oriented
# 39                           Cost analysis, budgeting
#
#                                  combined_description
# 0   Junior Accountant Assists in financial record-...
# 1   Financial Analyst Analyzes financial data to a...
# 2   Tax Consultant Advises clients on tax planning...
# 3   Audit Manager Oversees auditing processes, ens...
# 4   Entry-Level Software Developer  Programming la...
# 5   Full-Stack Developer Develops front-end and ba...
# 6   Mobile App Developer Specializes in creating a...
# 7   Software Architect Designs the overall structu...
# 8   Receptionist Manages front desk, answers calls...
# 9   Executive Assistant Provides comprehensive sup...
# 10  Office Manager Oversees administrative functio...
# 11  HR Administrator Supports HR tasks such as rec...
# 12  Sales Representative Generates leads, sells pr...
# 13  Account Manager Manages client accounts, ident...
# 14  Business Development Manager Identifies busine...
# 15  Sales Director Leads the sales department, set...
# 16  IT Support Specialist Provides technical suppo...
# 17  Network Administrator Manages and supports the...
# 18  Cybersecurity Analyst Protects systems from cy...
# 19  Data Scientist Analyzes complex data sets to i...
# 20  Payroll Specialist Manages payroll processing,...
# 21  Credit Analyst Assesses credit risk, evaluates...
# 22  Investment Banker Advises on and manages large...
# 23  Risk Manager Identifies financial risks and de...
# 24  QA Tester Tests software applications for bugs...
# 25  Backend Developer Focuses on server-side logic...
# 26  Frontend Developer Develops the user interface...
# 27  DevOps Engineer Streamlines software developme...
# 28  Administrative Assistant Assists in daily offi...
# 29  Data Entry Clerk Inputs and updates data into ...
# 30  Customer Service Rep Handles customer inquirie...
# 31  Sales Engineer Combines technical knowledge wi...
# 32  Territory Sales Manager Manages and grows sale...
# 33  Channel Sales Manager Manages sales through di...
# 34  Help Desk Technician Provides technical suppor...
# 35  System Administrator Manages and troubleshoots...
# 36  Cloud Solutions Architect Designs and deploys ...
# 37  Database Administrator Maintains and secures t...
# 38  Compliance Officer Ensures financial operation...
# 39  Cost Accountant Analyzes production costs, pre...

# %% [markdown]
# #### Specialization Classifier

# %% [markdown]
# ##### Tokenization and Embeddings with BERT

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load pre-trained BERT model and tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
bert_model = BertModel.from_pretrained('bert-base-uncased').to(device)

# %%
def get_bert_embeddings(bert_model, bert_tokenizer, text, device):
    with torch.no_grad():
        tokenized_text = bert_tokenizer.encode(text, add_special_tokens=True, return_tensors="pt").to(device)
        # outputs = bert_model(torch.LongTensor([token]))
        outputs = bert_model(tokenized_text)
        last_hidden_states = outputs.last_hidden_state.mean(dim=1).squeeze().detach().cpu().numpy()
    return last_hidden_states

# %%
df["embedded_combined_description"] = df['combined_description'].apply(lambda x: get_bert_embeddings(bert_model,tokenizer,x,device))

# %%
# To contain rows with specialization NaN values
df_nan_specialization = df[df['specialization'].isna()]
df = df.dropna()

# %% [markdown]
# ##### Experimentation with ML Models

# %%
# Split data
X_train, X_test, y_train, y_test = train_test_split(np.array(df["embedded_combined_description"].to_list()), df['specialization'], 
                                                    test_size=0.2, stratify = df['specialization'], random_state = 1)

# Initialize models
models = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'SVM': SVC(),
    'KNN': KNeighborsClassifier(),
}

# Train and evaluate models using cross-validation
print("Cross-validation results")
for name, model in models.items():
    scores = cross_val_score(model, X_train, y_train, cv=3, scoring='accuracy')
    print(f'{name} - Cross-Validation Accuracy: {scores.mean():.4f} (±{scores.std():.4f})')

# Test results
print("\nTest set results")
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f'{name} - Test Accuracy: {accuracy:.4f}')
# Out:
# Cross-validation results
# Logistic Regression - Cross-Validation Accuracy: 0.9333 (±0.0471)
# Decision Tree - Cross-Validation Accuracy: 0.5333 (±0.0943)
# Random Forest - Cross-Validation Accuracy: 0.7667 (±0.0471)
# SVM - Cross-Validation Accuracy: 0.7000 (±0.0816)
# KNN - Cross-Validation Accuracy: 0.8333 (±0.1247)
#
# Test set results
# Logistic Regression - Test Accuracy: 0.8750
# Decision Tree - Test Accuracy: 0.5000
# Random Forest - Test Accuracy: 0.7500
# SVM - Test Accuracy: 0.6250
# KNN - Test Accuracy: 0.7500

# %% [markdown]
# ##### GridSearch

# %%
# Initialize Logistic Regression model
logistic_regression_model = LogisticRegression()

# Perform grid search with cross-validation
param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100], 
    'max_iter': [100, 200, 300] 
}

grid_search = GridSearchCV(logistic_regression_model, param_grid, cv=3, scoring='accuracy', verbose=1)
grid_search.fit(X_train, y_train)

print("Best Parameters:", grid_search.best_params_)

best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Test Accuracy with Best Model: {accuracy:.4f}')
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# Best Parameters: {'C': 1, 'max_iter': 100}
# Test Accuracy with Best Model: 0.8750

# %%
# Save ML model
with open('models/spec_cls.pkl', 'wb') as file:
    pickle.dump(best_model, file)

# %% [markdown]
# #### Matching job using BERT embeddings

# %%
# Load ML model
with open('models/spec_cls.pkl', 'rb') as file:
    spec_cls_model = pickle.load(file)


def get_top_n_indices(array, n):
    top_n_indices = array.argsort()[::-1][:n]
    return top_n_indices

# Predict specialization
def predict_spec(spec_cls_model, bert_embedding, diff_threshold):
    predictions = spec_cls_model.predict_proba([bert_embedding])[0]
    top_2_indices = get_top_n_indices(predictions, 2)
    proba_difference = predictions[top_2_indices[0]] - predictions[top_2_indices[1]]
    if proba_difference >= diff_threshold:
        return [spec_cls_model.classes_[top_2_indices[0]]]
    return [spec_cls_model.classes_[idx] for idx in top_2_indices]

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
bert_model = BertModel.from_pretrained('bert-base-uncased').to(device)
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
# Sample input
user_sample_text = "I am responsible for determining the types of risks that could affect a company’s financial health, legal compliance or reputation"
user_embeddings = get_bert_embeddings(bert_model, tokenizer, user_sample_text, device)

# %%
# Perform filtering to omit unwanted matching of irrelavant specialization
predicted_spec = predict_spec(spec_cls_model, user_embeddings, diff_threshold = 0.15)
print(predicted_spec)
spec_filter = df["specialization"].isin(predicted_spec)
df[spec_filter]
# Out:
# ['Accounting & Finance']
#     job_id           job_title        specialization  \
# 0        1   Junior Accountant  Accounting & Finance
# 1        2   Financial Analyst  Accounting & Finance
# 2        3      Tax Consultant  Accounting & Finance
# 3        4       Audit Manager  Accounting & Finance
# 20      21  Payroll Specialist  Accounting & Finance
# 21      22      Credit Analyst  Accounting & Finance
# 22      23   Investment Banker  Accounting & Finance
# 23      24        Risk Manager  Accounting & Finance
# 38      39  Compliance Officer  Accounting & Finance
# 39      40     Cost Accountant  Accounting & Finance
#
#                                       job_description  \
# 0   Assists in financial record-keeping, prepares ...
# 1   Analyzes financial data to assist in business ...
# 2     Advises clients on tax planning and compliance.
# 3   Oversees auditing processes, ensures complianc...
# 20  Manages payroll processing, ensures accuracy a...
# 21  Assesses credit risk, evaluates financial stat...
# 22  Advises on and manages large financial transac...
# 23  Identifies financial risks and develops strate...
# 38  Ensures financial operations and transactions ...
# 39  Analyzes production costs, prepares budget rep...
#
#                                             skillsets  \
# 0   Accounting principles, Excel, attention to detail
# 1            Financial modeling, data analysis, Excel
# 2           Tax law, analytical skills, communication
# 3             Auditing, critical thinking, leadership
# 20
# 21                Financial analysis, risk assessment
# 22        Financial modelling, negotiation, valuation
# 23                 Risk management, analytical skills
# 38              Regulatory knowledge, detail-oriented
# 39                           Cost analysis, budgeting
#
#                                  combined_description  \
# 0   Junior Accountant Assists in financial record-...
# 1   Financial Analyst Analyzes financial data to a...
# 2   Tax Consultant Advises clients on tax planning...
# 3   Audit Manager Oversees auditing processes, ens...
# 20  Payroll Specialist Manages payroll processing,...
# 21  Credit Analyst Assesses credit risk, evaluates...
# 22  Investment Banker Advises on and manages large...
# 23  Risk Manager Identifies financial risks and de...
# 38  Compliance Officer Ensures financial operation...
# 39  Cost Accountant Analyzes production costs, pre...
#
#                         embedded_combined_description
# 0   [-0.16596301, 0.23873356, 0.28833672, 0.239333...
# 1   [-0.252826, -0.16007352, 0.2223302, 0.25238103...
# 2   [-0.17809252, 0.2923153, 0.16424774, 0.1462709...
# 3   [-0.14261793, 0.44612873, 0.17900231, 0.373750...
# 20  [-0.11196892, 0.142278, 0.1764309, 0.32669482,...
# 21  [0.028640425, 0.26161313, 0.09391271, 0.121830...
# 22  [-0.035764243, 0.2793286, 0.104248405, -0.1392...
# 23  [-0.26526693, 0.34649956, 0.05648968, 0.198842...
# 38  [-0.2585497, 0.25350386, 0.32698923, 0.1101090...
# 39  [-0.22156699, 0.27856416, 0.077836, 0.35531604...

# %%
df_filtered = df[spec_filter]
similarities = cosine_similarity(user_embeddings.reshape(1, -1), np.array(df_filtered["embedded_combined_description"].to_list()))[0]

# %%
# Predict top 3 job preference
def predict_job(df_filtered, user_embeddings):
    similarities = cosine_similarity(user_embeddings.reshape(1, -1), np.array(df_filtered["embedded_combined_description"].to_list()))[0]
    top_3_indices = get_top_n_indices(similarities, 3)
    recommended_jobs = [(df_filtered["job_title"].iloc[idx], df_filtered["job_description"].iloc[idx]) for idx in top_3_indices]
    return recommended_jobs

# %%
recommended_jobs = predict_job(df_filtered, user_embeddings)

# %%
for job, description in recommended_jobs:
    print(f"{job} - {description}")
# Out:
# Compliance Officer - Ensures financial operations and transactions comply with legal and regulatory requirements.
# Credit Analyst - Assesses credit risk, evaluates financial statements and investment opportunities.
# Risk Manager - Identifies financial risks and develops strategies to minimize impact.

# %%
# Back to processing specialization NaN values using trained ML model
df_nan_specialization
# Out:
#     job_id           job_title specialization  \
# 7        8  Software Architect            NaN
# 31      32      Sales Engineer            NaN
#
#                                       job_description  \
# 7   Designs the overall structure of software syst...
# 31  Combines technical knowledge with sales skills...
#
#                                  skillsets  \
# 7   System design, programming, leadership
# 31       Technical expertise, sales skills
#
#                                  combined_description  \
# 7   Software Architect Designs the overall structu...
# 31  Sales Engineer Combines technical knowledge wi...
#
#                         embedded_combined_description
# 7   [0.107352175, 0.60535455, 0.09075236, 0.033642...
# 31  [-0.032000657, 0.49894565, 0.503667, 0.1387504...

# %%
df_nan_specialization["specialization"] = df_nan_specialization["embedded_combined_description"].apply(lambda x: spec_cls_model.predict(x.reshape(1,-1))[0])

# %%
df_nan_specialization
# Out:
#     job_id           job_title           specialization  \
# 7        8  Software Architect  IT & Software Developer
# 31      32      Sales Engineer                    Sales
#
#                                       job_description  \
# 7   Designs the overall structure of software syst...
# 31  Combines technical knowledge with sales skills...
#
#                                  skillsets  \
# 7   System design, programming, leadership
# 31       Technical expertise, sales skills
#
#                                  combined_description  \
# 7   Software Architect Designs the overall structu...
# 31  Sales Engineer Combines technical knowledge wi...
#
#                         embedded_combined_description
# 7   [0.107352175, 0.60535455, 0.09075236, 0.033642...
# 31  [-0.032000657, 0.49894565, 0.503667, 0.1387504...

# %%
# Concatenate the processed df into a clean df
df_cleaned = pd.concat([df, df_nan_specialization], ignore_index=True)
df_cleaned.to_csv('data/mini-job-rec-dataset - jobs_data_clean.csv', index=False)
